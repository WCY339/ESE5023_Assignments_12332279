# %%
#导入Python工具包
import netCDF4 as nc
import numpy as np
import pandas as pd
import xarray as xr
from matplotlib import pyplot as plt
from matplotlib.gridspec import GridSpec
# %matplotlib inline

# %%
# 打开NOAA_NCDC_ERSST_v3b_SST.nc文件，读取数据集ds
ds = xr.open_dataset("NOAA_NCDC_ERSST_v3b_SST.nc",engine="netcdf4")
# 计算海洋表面温度的气候态
sst_clim = ds.sst.sel(lat=slice(-5, 5), lon=slice(190, 240)).groupby('time.month').mean()
sst_clim
# 按月份对数据集进行分组
group_data = ds.sst.sel(lat=slice(-5, 5), lon=slice(190, 240)).groupby('time.month')

# 去除气候态，得到异常值 
sst_anom = group_data - sst_clim
sst_anom

# 绘制全球海洋表面温度平均异常值
sst_anom.mean(dim=['lat', 'lon']).plot()
plt.show()

# %%
# 打开NOAA_NCDC_ERSST_v3b_SST.nc文件，读取数据集ds
ds = xr.open_dataset("NOAA_NCDC_ERSST_v3b_SST.nc", engine="netcdf4")

# 计算海温的气候态
sst_clim = ds.sst.sel(lat=slice(-5, 5), lon=slice(190, 240)).groupby('time.month').mean()

# 按月份对数据进行分组
group_data = ds.sst.sel(lat=slice(-5, 5), lon=slice(190, 240)).groupby('time.month')

# # 去除气候态，得到异常值,在经度和纬度两个纬度上计算异常值的均值
sst_anom = group_data - sst_clim
sst_anom_mean = sst_anom.mean(dim=['lat', 'lon'])

# 计算三个月的滑动平均值及厄尔尼诺3.4指数
sst_anom_mean_smoothed = sst_anom_mean.rolling(time=3, min_periods=1).mean()

# 创建画布及图形
fig,ax = plt.subplots(figsize=(10, 6))

# 绘制厄尔尼诺3.4指数
sst_anom_mean.plot(ax=ax, label='3mth running mean', color='black')

# 填充大于0的区域为红色，小于0的区域为蓝色
ax.fill_between(sst_anom_mean.time.values, sst_anom_mean, where=sst_anom_mean > 0, color='red', interpolate=True, alpha=0.5)
ax.fill_between(sst_anom_mean.time.values, sst_anom_mean, where=sst_anom_mean <= 0, color='blue', interpolate=True, alpha=0.5)

# 区分El Nino和La Nina事件
el_nino_threshold = 0.5
lanina_threshold = -0.5
ax.axhline(y=el_nino_threshold, color='r', linestyle='--', label='El Nino threshold')
ax.axhline(y=lanina_threshold, color='b', linestyle='--', label='La Nina threshold')

# 添加标题，标签以及图例
plt.title('SST Anomaly in Nino Region(5N-5S,120-170W)')
plt.xlabel('Year')
plt.ylabel('Anomaly in Degrees C')
plt.legend()

# 显示图形
plt.show()

# %%
# Open a netCDF4 file
da = xr.open_dataset("CERES_EBAF-TOA_200003-201701.nc",engine="netcdf4")
da
# Out:
# <xarray.Dataset>
# Dimensions:                      (lon: 360, time: 203, lat: 180)
# Coordinates:
#   * lon                          (lon) float32 0.5 1.5 2.5 ... 357.5 358.5 359.5
#   * time                         (time) datetime64[ns] 2000-03-15 ... 2017-01-15
#   * lat                          (lat) float32 -89.5 -88.5 -87.5 ... 88.5 89.5
# Data variables: (12/14)
#     toa_sw_all_mon               (time, lat, lon) float32 ...
#     toa_lw_all_mon               (time, lat, lon) float32 ...
#     toa_net_all_mon              (time, lat, lon) float32 ...
#     toa_sw_clr_mon               (time, lat, lon) float32 ...
#     toa_lw_clr_mon               (time, lat, lon) float32 ...
#     toa_net_clr_mon              (time, lat, lon) float32 ...
#     ...                           ...
#     toa_cre_net_mon              (time, lat, lon) float32 ...
#     solar_mon                    (time, lat, lon) float32 ...
#     cldarea_total_daynight_mon   (time, lat, lon) float32 ...
#     cldpress_total_daynight_mon  (time, lat, lon) float32 ...
#     cldtemp_total_daynight_mon   (time, lat, lon) float32 ...
#     cldtau_total_day_mon         (time, lat, lon) float32 ...
# Attributes:
#     title:             CERES EBAF (Energy Balanced and Filled) TOA Fluxes. Mo...
#     institution:       NASA/LaRC (Langley Research Center) Hampton, Va
#     Conventions:       CF-1.4
#     comment:           Data is from East to West and South to North.
#     Version:           Edition 4.0; Release Date March 7, 2017
#     Fill_Value:        Fill Value is -999.0
#     DOI:               10.5067/TERRA+AQUA/CERES/EBAF-TOA_L3B.004.0
#     Production_Files:  List of files used in creating the present Master netC...

# %%
# 读取数据集
da = xr.open_dataset("CERES_EBAF-TOA_200003-201701.nc", engine="netcdf4")

# 计算时间平均值
toa_lw_mean = da['toa_lw_all_mon'].mean(dim='time')# 计算 TOA 长波辐射的时间平均值
toa_sw_mean = da['toa_sw_all_mon'].mean(dim='time')# 计算 TOA 短波辐射的时间平均值
solar_mean = da['solar_mon'].mean(dim='time')# 计算太阳辐射的时间平均值

# 计算 TOA 净辐射
toa_net_calc =solar_mean - toa_sw_mean - toa_lw_mean

# 创建不规则的子图网格
fig = plt.figure(figsize=(18, 8))
gs = GridSpec(2, 3, width_ratios=[1, 1, 1], height_ratios=[1, 1])

# 绘制 TOA 长波辐射空间分布图
ax0 = plt.subplot(gs[0, 0])
toa_lw_mean.plot(ax=ax0, cmap='coolwarm', cbar_kwargs={'label': 'W m$^{-2}$'})
ax0.set_title('TOA Longwave Flux')

# 绘制 TOA 短波辐射空间分布图
ax1 = plt.subplot(gs[0, 1])
toa_sw_mean.plot(ax=ax1, cmap='YlGnBu', cbar_kwargs={'label': 'W m$^{-2}$'})
ax1.set_title('TOA Shortwave Flux')

# 绘制太阳辐射空间分布图
ax2 = plt.subplot(gs[0, 2])
solar_mean.plot(ax=ax2, cmap='YlOrBr', cbar_kwargs={'label': 'W m$^{-2}$'})
ax2.set_title('Solar Radiation')

# 绘制TOA 净辐射(经计算)空间分布图
ax3 = plt.subplot(gs[1, 0])
toa_net_calc.plot(ax=ax3, cmap='RdBu_r', cbar_kwargs={'label': 'W m$^{-2}$'})
ax3.set_title('TOA Net Flux (Calculated)')

# 绘制TOA 净辐射(数据集)空间分布图
ax4 = plt.subplot(gs[1, 1])
da['toa_net_all_mon'].mean(dim='time').plot(ax=ax4, cmap='PuOr', cbar_kwargs={'label': 'W m$^{-2}$'})
ax4.set_title('TOA Net Flux (Dataset)')

# 隐藏空白子图图框
fig.delaxes(plt.subplot(gs[1, 2]))

plt.tight_layout()
plt.show()

# %%
# 地球半径（以米为单位）
earth_radius = 6371e3
# 计算纬度和经度的差分（以弧度为单位）
dlat_rad = np.deg2rad(np.diff(da['lat'].values))
dlon_rad = np.deg2rad(np.diff(da['lon'].values))
# 添加额外的差分，以匹配网格单元的大小
dlat_rad = np.append(dlat_rad, dlat_rad[-1])
dlon_rad = np.append(dlon_rad, dlon_rad[-1])
# 计算每个纬度权重及网格面积
lat_edges = np.deg2rad(da['lat'].values) - dlat_rad / 2
lat_edges = np.append(lat_edges, lat_edges[-1] + dlat_rad[-1])  # Add the last edge
weights = np.sin(lat_edges[1:]) - np.sin(lat_edges[:-1])
grid_area_lat = earth_radius**2 * dlat_rad * weights
# 计算每个单元的总网格面积
grid_area = np.outer(grid_area_lat, dlon_rad)
# 计算三个变量的时间平均值
toa_lw_mean = da['toa_lw_all_mon'].mean(dim='time')
toa_sw_mean = da['toa_sw_all_mon'].mean(dim='time')
solar_mean = da['solar_mon'].mean(dim='time')
# 使用 grid_area_da 来加权平均
grid_area_da = xr.DataArray(grid_area, dims=["lat", "lon"], coords={"lat": da['lat'], "lon": da['lon']})
solar_mean = (da['solar_mon'].mean(dim='time') * grid_area_da).sum(dim=('lon', 'lat')) / grid_area_da.sum()
toa_lw_mean = (da['toa_lw_all_mon'].mean(dim='time') * grid_area_da).sum(dim=('lon', 'lat')) / grid_area_da.sum()
toa_sw_mean = (da['toa_sw_all_mon'].mean(dim='time') * grid_area_da).sum(dim=('lon', 'lat')) / grid_area_da.sum()
# 打印结果
print('TOA Incoming Solar Flux:', solar_mean.values)
print('TOA Outgoing Longwave Flux:', toa_lw_mean.values)
print('TOA Outgoing Shortwave Flux:', toa_sw_mean.values)
# Out:
# TOA Incoming Solar Flux: 340.28513
# TOA Outgoing Longwave Flux: 240.268
# TOA Outgoing Shortwave Flux: 99.139046

# %%
# 计算每个1度纬度带的净辐射总量
net_flux_by_latitude = da['toa_net_all_mon'].sum(dim='lon')

# 绘制柱状图
plt.bar(net_flux_by_latitude['lat'], net_flux_by_latitude.mean(dim='time'))

# 添加标签和标题
plt.xlabel('Latitude (degrees_north)')
plt.ylabel('Net Flux (W m-1)')
plt.title('Net Flux by Latitude Band')

# 显示图形
plt.show()

# %%
# 计算低云和高云区的时间平均输出短波和长波辐射
low_cloud_mask = da['cldarea_total_daynight_mon'] <= 25
high_cloud_mask = da['cldarea_total_daynight_mon'] >= 75

toa_cre_sw_low_cloud = da['toa_cre_sw_mon'].where(low_cloud_mask).mean(dim='time')
toa_cre_lw_low_cloud = da['toa_cre_lw_mon'].where(low_cloud_mask).mean(dim='time')

toa_cre_sw_high_cloud = da['toa_cre_sw_mon'].where(high_cloud_mask).mean(dim='time')
toa_cre_lw_high_cloud = da['toa_cre_lw_mon'].where(high_cloud_mask).mean(dim='time')

# 绘制合成图
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# 低云区输出短波辐射
toa_cre_sw_low_cloud.plot(ax=axes[0, 0], cmap='coolwarm', robust=True)
axes[0, 0].set_title('Low Cloud SW Radiation')

# 低云区输出长波辐射
toa_cre_lw_low_cloud.plot(ax=axes[0, 1], cmap='coolwarm', robust=True)
axes[0, 1].set_title('Low Cloud LW Radiation')

# 高云区输出短波辐射
toa_cre_sw_high_cloud.plot(ax=axes[1, 0], cmap='coolwarm', robust=True)
axes[1, 0].set_title('High Cloud SW Radiation')

# 高云区输出长波辐射
toa_cre_lw_high_cloud.plot(ax=axes[1, 1], cmap='coolwarm', robust=True)
axes[1, 1].set_title('High Cloud LW Radiation')

plt.tight_layout()
plt.show()

# %%
# 定义低云区和高云区
low_cloud_mask = da['cldarea_total_daynight_mon'] <= 25
high_cloud_mask = da['cldarea_total_daynight_mon'] >= 75

# 计算全球短波辐射和长波辐射平均值
toa_sw_all_global = da['toa_sw_all_mon'].mean(dim=('lon', 'lat','time'))
toa_lw_all_global = da['toa_lw_all_mon'].mean(dim=('lon', 'lat','time'))

# 在低云区合成
toa_sw_low_cloud = da['toa_sw_all_mon'].where(low_cloud_mask).mean(dim=('lon', 'lat','time'))
toa_lw_low_cloud = da['toa_lw_all_mon'].where(low_cloud_mask).mean(dim=('lon', 'lat','time'))

# 在高云区合成
toa_sw_high_cloud = da['toa_sw_all_mon'].where(high_cloud_mask).mean(dim=('lon', 'lat','time'))
toa_lw_high_cloud = da['toa_lw_all_mon'].where(high_cloud_mask).mean(dim=('lon', 'lat','time'))

# 打印结果
print("全球平均短波辐射:", toa_sw_all_global.values)
print("全球平均长波辐射:", toa_lw_all_global.values)
print("低云区平均短波辐射:", toa_sw_low_cloud.values)
print("低云区平均长波辐射:", toa_lw_low_cloud.values)
print("高云区平均短波辐射:", toa_sw_high_cloud.values)
print("高云区平均长波辐射:", toa_lw_high_cloud.values)
# Out:
# 全球平均短波辐射: 102.30436
# 全球平均长波辐射: 224.7552
# 低云区平均短波辐射: 97.11116
# 低云区平均长波辐射: 247.33109
# 高云区平均短波辐射: 111.76594
# 高云区平均长波辐射: 215.39049

# %%
dm = xr.open_dataset('merged.nc')
dm.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	time = 36 ;
# 	bnds = 2 ;
# 	lon = 360 ;
# 	lat = 150 ;
#
# variables:
# 	datetime64[ns] time(time) ;
# 		time:standard_name = time ;
# 		time:long_name = time ;
# 		time:bounds = time_bnds ;
# 		time:axis = T ;
# 	datetime64[ns] time_bnds(time, bnds) ;
# 	float32 lon(lon) ;
# 		lon:standard_name = longitude ;
# 		lon:long_name = longitude ;
# 		lon:units = degrees_east ;
# 		lon:axis = X ;
# 	float32 lat(lat) ;
# 		lat:standard_name = latitude ;
# 		lat:long_name = latitude ;
# 		lat:units = degrees_north ;
# 		lat:axis = Y ;
# 	float32 Swnet_tavg(time, lat, lon) ;
# 		Swnet_tavg:standard_name = surface_net_downward_shortwave_flux ;
# 		Swnet_tavg:long_name = Net short wave radiation flux ;
# 		Swnet_tavg:units = W m-2 ;
# 		Swnet_tavg:cell_methods = time: mean ;
# 		Swnet_tavg:vmin = 0.0 ;
# 		Swnet_tavg:vmax = 317.6919250488281 ;
# 	float32 Lwnet_tavg(time, lat, lon) ;
# 		Lwnet_tavg:standard_name = surface_net_downward_longwave_flux ;
# 		Lwnet_tavg:long_name = Net long-wave radiation flux ;
# 		Lwnet_tavg:units = W m-2 ;
# 		Lwnet_tavg:cell_methods = time: mean ;
# 		Lwnet_tavg:vmin = -155.94358825683594 ;
# 		Lwnet_tavg:vmax = 43.56669235229492 ;
# 	float32 Qle_tavg(time, lat, lon) ;
# 		Qle_tavg:standard_name = surface_upward_latent_heat_flux ;
# 		Qle_tavg:long_name = Latent heat net flux ;
# 		Qle_tavg:units = W m-2 ;
# 		Qle_tavg:cell_methods = time: mean ;
# 		Qle_tavg:vmin = -0.7231138348579407 ;
# 		Qle_tavg:vmax = 260.607666015625 ;
# 	float32 Qh_tavg(time, lat, lon) ;
# 		Qh_tavg:standard_name = surface_upward_sensible_heat_flux ;
# 		Qh_tavg:long_name = Sensible heat net flux ;
# 		Qh_tavg:units = W m-2 ;
# 		Qh_tavg:cell_methods = time: mean ;
# 		Qh_tavg:vmin = -158.29574584960938 ;
# 		Qh_tavg:vmax = 192.0059356689453 ;
# 	float32 Qg_tavg(time, lat, lon) ;
# 		Qg_tavg:standard_name = downward_heat_flux_in_soil ;
# 		Qg_tavg:long_name = Heat flux ;
# 		Qg_tavg:units = W m-2 ;
# 		Qg_tavg:cell_methods = time: mean ;
# 		Qg_tavg:vmin = -25.909765243530273 ;
# 		Qg_tavg:vmax = 6.8063645362854 ;
# 	float32 Snowf_tavg(time, lat, lon) ;
# 		Snowf_tavg:standard_name = snowfall_flux ;
# 		Snowf_tavg:long_name = Snow precipitation rate ;
# 		Snowf_tavg:units = kg m-2 s-1 ;
# 		Snowf_tavg:cell_methods = time: mean ;
# 		Snowf_tavg:vmin = 0.0 ;
# 		Snowf_tavg:vmax = 0.0001281318545807153 ;
# 	float32 Rainf_tavg(time, lat, lon) ;
# 		Rainf_tavg:standard_name = rainfall_flux ;
# 		Rainf_tavg:long_name = Rain precipitation rate ;
# 		Rainf_tavg:units = kg m-2 s-1 ;
# 		Rainf_tavg:cell_methods = time: mean ;
# 		Rainf_tavg:vmin = 0.0 ;
# 		Rainf_tavg:vmax = 0.0002523036382626742 ;
# 	float32 Evap_tavg(time, lat, lon) ;
# 		Evap_tavg:standard_name = water_evaporation_flux ;
# 		Evap_tavg:long_name = Evapotranspiration ;
# 		Evap_tavg:units = kg m-2 s-1 ;
# 		Evap_tavg:cell_methods = time: mean ;
# 		Evap_tavg:vmin = -3.100822141277604e-06 ;
# 		Evap_tavg:vmax = 0.00010565764387138188 ;
# 	float32 Qs_acc(time, lat, lon) ;
# 		Qs_acc:standard_name = surface_runoff_amount ;
# 		Qs_acc:long_name = Storm surface runoff ;
# 		Qs_acc:units = kg m-2 ;
# 		Qs_acc:cell_methods = time: mean ;
# 		Qs_acc:vmin = 0.0 ;
# 		Qs_acc:vmax = 2.2818949222564697 ;
# 	float32 Qsb_acc(time, lat, lon) ;
# 		Qsb_acc:standard_name = subsurface_runoff_amount ;
# 		Qsb_acc:long_name = Baseflow-groundwater runoff ;
# 		Qsb_acc:units = kg m-2 ;
# 		Qsb_acc:cell_methods = time: mean ;
# 		Qsb_acc:vmin = 0.0 ;
# 		Qsb_acc:vmax = 0.6055534482002258 ;
# 	float32 Qsm_acc(time, lat, lon) ;
# 		Qsm_acc:standard_name = surface_snow_melt_amount ;
# 		Qsm_acc:long_name = Snow melt ;
# 		Qsm_acc:units = kg m-2 ;
# 		Qsm_acc:cell_methods = time: mean ;
# 		Qsm_acc:vmin = 0.0 ;
# 		Qsm_acc:vmax = 0.8009302616119385 ;
# 	float32 SnowT_tavg(time, lat, lon) ;
# 		SnowT_tavg:standard_name = temperature_in_surface_snow ;
# 		SnowT_tavg:long_name = Snow Surface temperature ;
# 		SnowT_tavg:units = K ;
# 		SnowT_tavg:cell_methods = time: mean ;
# 		SnowT_tavg:vmin = 227.1201629638672 ;
# 		SnowT_tavg:vmax = 311.4012145996094 ;
# 	float32 AvgSurfT_inst(time, lat, lon) ;
# 		AvgSurfT_inst:standard_name = surface_temperature ;
# 		AvgSurfT_inst:long_name = Average Surface Skin temperature ;
# 		AvgSurfT_inst:units = K ;
# 		AvgSurfT_inst:cell_methods = time: mean ;
# 		AvgSurfT_inst:vmin = 227.10275268554688 ;
# 		AvgSurfT_inst:vmax = 311.2429504394531 ;
# 	float32 Albedo_inst(time, lat, lon) ;
# 		Albedo_inst:standard_name = surface_albedo ;
# 		Albedo_inst:long_name = Albedo ;
# 		Albedo_inst:units = % ;
# 		Albedo_inst:cell_methods = time: mean ;
# 		Albedo_inst:vmin = 7.426558494567871 ;
# 		Albedo_inst:vmax = 62.35662078857422 ;
# 	float32 SWE_inst(time, lat, lon) ;
# 		SWE_inst:standard_name = surface_snow_amount ;
# 		SWE_inst:long_name = Snow depth water equivalent ;
# 		SWE_inst:units = kg m-2 ;
# 		SWE_inst:cell_methods = time: mean ;
# 		SWE_inst:vmin = 0.0 ;
# 		SWE_inst:vmax = 1633.9552001953125 ;
# 	float32 SnowDepth_inst(time, lat, lon) ;
# 		SnowDepth_inst:standard_name = surface_snow_thickness ;
# 		SnowDepth_inst:long_name = Snow depth ;
# 		SnowDepth_inst:units = m ;
# 		SnowDepth_inst:cell_methods = time: mean ;
# 		SnowDepth_inst:vmin = 0.0 ;
# 		SnowDepth_inst:vmax = 3.9176697731018066 ;
# 	float32 SoilMoist_S_inst(time, lat, lon) ;
# 		SoilMoist_S_inst:standard_name = soil_moisture_content ;
# 		SoilMoist_S_inst:long_name = Surface Soil moisture ;
# 		SoilMoist_S_inst:units = kg m-2 ;
# 		SoilMoist_S_inst:cell_methods = time: mean ;
# 		SoilMoist_S_inst:vmin = 0.00700479606166482 ;
# 		SoilMoist_S_inst:vmax = 8.925436019897461 ;
# 	float32 SoilMoist_RZ_inst(time, lat, lon) ;
# 		SoilMoist_RZ_inst:standard_name = soil_moisture_content ;
# 		SoilMoist_RZ_inst:long_name = Root Zone Soil moisture ;
# 		SoilMoist_RZ_inst:units = kg m-2 ;
# 		SoilMoist_RZ_inst:cell_methods = time: mean ;
# 		SoilMoist_RZ_inst:vmin = 32.60118103027344 ;
# 		SoilMoist_RZ_inst:vmax = 468.2303771972656 ;
# 	float32 SoilMoist_P_inst(time, lat, lon) ;
# 		SoilMoist_P_inst:standard_name = soil_moisture_content ;
# 		SoilMoist_P_inst:long_name = Profile Soil moisture ;
# 		SoilMoist_P_inst:units = kg m-2 ;
# 		SoilMoist_P_inst:cell_methods = time: mean ;
# 		SoilMoist_P_inst:vmin = 111.5224838256836 ;
# 		SoilMoist_P_inst:vmax = 3961.697021484375 ;
# 	float32 SoilTMP0_10cm_inst(time, lat, lon) ;
# 		SoilTMP0_10cm_inst:standard_name = soil_temperature ;
# 		SoilTMP0_10cm_inst:long_name = Soil temperature ;
# 		SoilTMP0_10cm_inst:units = K ;
# 		SoilTMP0_10cm_inst:cell_methods = time: mean ;
# 		SoilTMP0_10cm_inst:vmin = 230.511474609375 ;
# 		SoilTMP0_10cm_inst:vmax = 310.8994140625 ;
# 	float32 SoilTMP10_29cm_inst(time, lat, lon) ;
# 		SoilTMP10_29cm_inst:standard_name = soil_temperature ;
# 		SoilTMP10_29cm_inst:long_name = Soil temperature ;
# 		SoilTMP10_29cm_inst:units = K ;
# 		SoilTMP10_29cm_inst:cell_methods = time: mean ;
# 		SoilTMP10_29cm_inst:vmin = 231.5760955810547 ;
# 		SoilTMP10_29cm_inst:vmax = 309.9587097167969 ;
# 	float32 SoilTMP29_68cm_inst(time, lat, lon) ;
# 		SoilTMP29_68cm_inst:standard_name = soil_temperature ;
# 		SoilTMP29_68cm_inst:long_name = Soil temperature ;
# 		SoilTMP29_68cm_inst:units = K ;
# 		SoilTMP29_68cm_inst:cell_methods = time: mean ;
# 		SoilTMP29_68cm_inst:vmin = 233.74240112304688 ;
# 		SoilTMP29_68cm_inst:vmax = 308.1799011230469 ;
# 	float32 SoilTMP68_144cm_inst(time, lat, lon) ;
# 		SoilTMP68_144cm_inst:standard_name = soil_temperature ;
# 		SoilTMP68_144cm_inst:long_name = Soil temperature ;
# 		SoilTMP68_144cm_inst:units = K ;
# 		SoilTMP68_144cm_inst:cell_methods = time: mean ;
# 		SoilTMP68_144cm_inst:vmin = 238.00546264648438 ;
# 		SoilTMP68_144cm_inst:vmax = 307.711669921875 ;
# 	float32 SoilTMP144_295cm_inst(time, lat, lon) ;
# 		SoilTMP144_295cm_inst:standard_name = soil_temperature ;
# 		SoilTMP144_295cm_inst:long_name = Soil temperature ;
# 		SoilTMP144_295cm_inst:units = K ;
# 		SoilTMP144_295cm_inst:cell_methods = time: mean ;
# 		SoilTMP144_295cm_inst:vmin = 245.31507873535156 ;
# 		SoilTMP144_295cm_inst:vmax = 309.0823059082031 ;
# 	float32 SoilTMP295_1295cm_inst(time, lat, lon) ;
# 		SoilTMP295_1295cm_inst:standard_name = soil_temperature ;
# 		SoilTMP295_1295cm_inst:long_name = Soil temperature ;
# 		SoilTMP295_1295cm_inst:units = K ;
# 		SoilTMP295_1295cm_inst:cell_methods = time: mean ;
# 		SoilTMP295_1295cm_inst:vmin = 251.1204071044922 ;
# 		SoilTMP295_1295cm_inst:vmax = 309.65673828125 ;
# 	float32 ECanop_tavg(time, lat, lon) ;
# 		ECanop_tavg:standard_name = evaporation_flux_from_canopy ;
# 		ECanop_tavg:long_name = Canopy water evaporation ;
# 		ECanop_tavg:units = W m-2 ;
# 		ECanop_tavg:cell_methods = time: mean ;
# 		ECanop_tavg:vmin = -2.556706190109253 ;
# 		ECanop_tavg:vmax = 79.27970886230469 ;
# 	float32 TVeg_tavg(time, lat, lon) ;
# 		TVeg_tavg:standard_name = transpiration_flux_from_veg ;
# 		TVeg_tavg:long_name = Transpiration ;
# 		TVeg_tavg:units = W m-2 ;
# 		TVeg_tavg:cell_methods = time: mean ;
# 		TVeg_tavg:vmin = -0.0017954237991943955 ;
# 		TVeg_tavg:vmax = 148.25582885742188 ;
# 	float32 ESoil_tavg(time, lat, lon) ;
# 		ESoil_tavg:standard_name = evaporation_flux_from_soil ;
# 		ESoil_tavg:long_name = Direct Evaporation from Bare Soil ;
# 		ESoil_tavg:units = W m-2 ;
# 		ESoil_tavg:cell_methods = time: mean ;
# 		ESoil_tavg:vmin = -0.00020178953127469867 ;
# 		ESoil_tavg:vmax = 158.46258544921875 ;
# 	float32 CanopInt_inst(time, lat, lon) ;
# 		CanopInt_inst:standard_name = canopy_water_amount ;
# 		CanopInt_inst:long_name = Plant canopy surface water ;
# 		CanopInt_inst:units = kg m-2 ;
# 		CanopInt_inst:cell_methods = time: mean ;
# 		CanopInt_inst:vmin = 0.0 ;
# 		CanopInt_inst:vmax = 0.46206048130989075 ;
# 	float32 ACond_tavg(time, lat, lon) ;
# 		ACond_tavg:standard_name = aerodynamic_conductance ;
# 		ACond_tavg:long_name = Aerodynamic conductance ;
# 		ACond_tavg:units = m s-1 ;
# 		ACond_tavg:cell_methods = time: mean ;
# 		ACond_tavg:vmin = 0.0017717847367748618 ;
# 		ACond_tavg:vmax = 0.7631528377532959 ;
# 	float32 TWS_inst(time, lat, lon) ;
# 		TWS_inst:standard_name = terrestrial_water_storage ;
# 		TWS_inst:long_name = Terrestrial water storage ;
# 		TWS_inst:units = mm ;
# 		TWS_inst:cell_methods = time: mean ;
# 		TWS_inst:vmin = 111.45982360839844 ;
# 		TWS_inst:vmax = 3961.79052734375 ;
# 	float32 Wind_f_inst(time, lat, lon) ;
# 		Wind_f_inst:standard_name = wind_speed ;
# 		Wind_f_inst:long_name = Wind speed ;
# 		Wind_f_inst:units = m s-1 ;
# 		Wind_f_inst:cell_methods = time: mean ;
# 		Wind_f_inst:vmin = 0.5409321784973145 ;
# 		Wind_f_inst:vmax = 11.494964599609375 ;
# 	float32 Rainf_f_tavg(time, lat, lon) ;
# 		Rainf_f_tavg:standard_name = precipitation_flux ;
# 		Rainf_f_tavg:long_name = Total precipitation rate ;
# 		Rainf_f_tavg:units = kg m-2 s-1 ;
# 		Rainf_f_tavg:cell_methods = time: mean ;
# 		Rainf_f_tavg:vmin = 0.0 ;
# 		Rainf_f_tavg:vmax = 0.0002523036382626742 ;
# 	float32 Tair_f_inst(time, lat, lon) ;
# 		Tair_f_inst:standard_name = air_temperature ;
# 		Tair_f_inst:long_name = Temperature ;
# 		Tair_f_inst:units = K ;
# 		Tair_f_inst:cell_methods = time: mean ;
# 		Tair_f_inst:vmin = 225.07180786132812 ;
# 		Tair_f_inst:vmax = 306.8051452636719 ;
# 	float32 Qair_f_inst(time, lat, lon) ;
# 		Qair_f_inst:standard_name = specific_humidity ;
# 		Qair_f_inst:long_name = Specific humidity ;
# 		Qair_f_inst:units = kg kg-1 ;
# 		Qair_f_inst:cell_methods = time: mean ;
# 		Qair_f_inst:vmin = 2.9128694222890772e-05 ;
# 		Qair_f_inst:vmax = 0.023642515763640404 ;
# 	float32 Psurf_f_inst(time, lat, lon) ;
# 		Psurf_f_inst:standard_name = surface_air_pressure ;
# 		Psurf_f_inst:long_name = Pressure ;
# 		Psurf_f_inst:units = Pa ;
# 		Psurf_f_inst:cell_methods = time: mean ;
# 		Psurf_f_inst:vmin = 49905.42578125 ;
# 		Psurf_f_inst:vmax = 104029.7265625 ;
# 	float32 SWdown_f_tavg(time, lat, lon) ;
# 		SWdown_f_tavg:standard_name = surface_downwelling_shortwave_flux_in_air ;
# 		SWdown_f_tavg:long_name = Downward short-wave radiation flux ;
# 		SWdown_f_tavg:units = W m-2 ;
# 		SWdown_f_tavg:cell_methods = time: mean ;
# 		SWdown_f_tavg:vmin = 0.0 ;
# 		SWdown_f_tavg:vmax = 370.3979797363281 ;
# 	float32 LWdown_f_tavg(time, lat, lon) ;
# 		LWdown_f_tavg:standard_name = surface_downwelling_longwave_flux_in_air ;
# 		LWdown_f_tavg:long_name = Downward long-wave radiation flux ;
# 		LWdown_f_tavg:units = W m-2 ;
# 		LWdown_f_tavg:cell_methods = time: mean ;
# 		LWdown_f_tavg:vmin = 127.64710235595703 ;
# 		LWdown_f_tavg:vmax = 436.82037353515625 ;
#
# // global attributes:
# 	:CDI = Climate Data Interface version 1.9.8 (https://mpimet.mpg.de/cdi) ;
# 	:Conventions = CF-1.6 ;
# 	:history = created on date: 2020-09-04T03:14:44.499 ;
# 	:source = CLSM_F2.5 forced with Princeton_V2.2 ;
# 	:institution = NASA GSFC ;
# 	:missing_value = -9999.0 ;
# 	:tavg definition: = past 3-hour average ;
# 	:acc definition: = past 3-hour accumulation ;
# 	:inst definition: = instantaneous ;
# 	:title = GLDAS2.0 LIS land surface model output monthly mean ;
# 	:references = Rodell_etal_BAMS_2004, Kumar_etal_EMS_2006, Peters-Lidard_etal_ISSE_2007 ;
# 	:conventions = CF-1.6 ;
# 	:comment = website: https://ldas.gsfc.nasa.gov/gldas, https://lis.gsfc.nasa.gov/ ;
# 	:MAP_PROJECTION = EQUIDISTANT CYLINDRICAL ;
# 	:SOUTH_WEST_CORNER_LAT = -59.5 ;
# 	:SOUTH_WEST_CORNER_LON = -179.5 ;
# 	:DX = 1.0 ;
# 	:DY = 1.0 ;
# 	:CDO = Climate Data Operators version 1.9.8 (https://mpimet.mpg.de/cdo) ;
# }

# %%
# 打开下载的数据集，并保存在变量dm中
dm = xr.open_dataset("merged.nc",engine="netcdf4")
# 计算显热净通量的气候态
Qh_tavg_clim = dm['Qh_tavg'].groupby('time.month').mean()
Qh_tavg_clim
# 按月对数据进行分组
group_data = dm['Qh_tavg'].groupby('time.month')

# 计算显热净通量的异常值
Qh_tavg_anom = group_data - Qh_tavg_clim
Qh_tavg_anom

# 绘制结果图
Qh_tavg_anom.mean(dim=['lat', 'lon']).plot()

# %%
# 加载数据集
ds = xr.open_dataset('merged.nc')

# 绘制短波净辐射通量的时间序列图
plt.figure(figsize=(12, 6))
plt.plot(dm['time'], dm['Qle_tavg'].mean(dim=('lat', 'lon')))
plt.xlabel('Time')
plt.ylabel('Net Shortwave Radiation Flux')
plt.title('Time Series of Net Shortwave Radiation Flux')
plt.show()

# 绘制全球平均短波净辐射通量分布图
global_mean_swnet = ds['Swnet_tavg'].mean(dim='time')

plt.figure(figsize=(12, 6))
global_mean_swnet.plot()
plt.title('Global Mean Net Shortwave Radiation Flux')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# 绘制散点图
temperature = ds['SnowT_tavg'].mean(dim='time')
precipitation = ds['Rainf_tavg'].mean(dim='time')
plt.figure(figsize=(12, 6))
plt.scatter(temperature, precipitation, c='blue', alpha=0.5)
plt.title('Temperature vs. Precipitation')
plt.xlabel('Snow Surface Temperature (K)')
plt.ylabel('Rain Precipitation Rate (kg m-2 s-1)')
plt.show()
# 绘制降水量在地图上的分布
plt.figure(figsize=(12, 6))
ds['Rainf_tavg'].isel(time=0).plot.pcolormesh()
plt.title('Rainfall Distribution')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# 绘制显热通量的直方图
plt.figure(figsize=(12, 6))
plt.hist(dm['Qh_tavg'].values.flatten(), bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Sensible Heat Net Flux (W/m^2)')
plt.ylabel('Frequency')
plt.title('Distribution of Sensible Heat Net Flux')
plt.show()

# %%
# 加载数据集
ds = xr.open_dataset('merged.nc')

# 绘制短波净辐射通量的时间序列图
plt.figure(figsize=(12, 6))
plt.plot(ds['time'], ds['Qle_tavg'].mean(dim=('lat', 'lon')))
plt.xlabel('Time')
plt.ylabel('Net Shortwave Radiation Flux')
plt.title('Time Series of Net Shortwave Radiation Flux')
plt.show()

# 绘制全球平均短波净辐射通量分布图
global_mean_swnet = ds['Swnet_tavg'].mean(dim='time')

plt.figure(figsize=(12, 6))
global_mean_swnet.plot()
plt.title('Global Mean Net Shortwave Radiation Flux')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# 绘制降雨速率与雪表面温度散点图
temperature = ds['SnowT_tavg'].mean(dim='time')
precipitation = ds['Rainf_tavg'].mean(dim='time')
plt.figure(figsize=(12, 6))
plt.scatter(temperature, precipitation, c='blue', alpha=0.5)
plt.title('Precipitation vs. Temperature')
plt.xlabel('Snow Surface Temperature (K)')
plt.ylabel('Rain Precipitation Rate (kg m-2 s-1)')
plt.show()

# 绘制降水量在地图上的分布
plt.figure(figsize=(12, 6))
ds['Rainf_tavg'].isel(time=0).plot.pcolormesh()
plt.title('Rainfall Distribution')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# 绘制显热通量的直方图
plt.figure(figsize=(12, 6))
plt.hist(ds['Qh_tavg'].values.flatten(), bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Sensible Heat Net Flux (W/m^2)')
plt.ylabel('Frequency')
plt.title('Distribution of Sensible Heat Net Flux')
plt.show()
